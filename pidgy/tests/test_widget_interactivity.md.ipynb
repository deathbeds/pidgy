# %%
### Interactive templates

these examples demonstrate the abilities of `pidgy`'s interactive widgets.

party out of order.

    import pidgy
    from IPython import get_ipython
    from poser import *
    if get_ipython():
        # %matplotlib agg
# Out:
# ### Interactive templates
#
# these examples demonstrate the abilities of `pidgy`'s interactive widgets.
#
# party out of order.
#
#     import pidgy
#     from IPython import get_ipython
#     from poser import *
#     if get_ipython():
#         %matplotlib agg

# %%
## the c🍪🍪kie demo.

bret viktor's tanglejs demonstrates a future world where mechanical type becomes flexible hypertext that effects the document context.

below we recreate the c🍪🍪kie demo. 

[tanglejs]: http://worrydream.com/Tangle/
[ipytangle]: https://github.com/bollwyvl/ipytangle
[revisit-tangle]: https://blog.ouseful.info/2017/07/13/time-to-revisit-tangle/
# Out:
# ## the c🍪🍪kie demo.
#
# bret viktor's tanglejs demonstrates a future world where mechanical type becomes flexible hypertext that effects the document context.
#
# below we recreate the c🍪🍪kie demo.
#
# [tanglejs]: http://worrydream.com/Tangle/
# [ipytangle]: https://github.com/bollwyvl/ipytangle
# [revisit-tangle]: https://blog.ouseful.info/2017/07/13/time-to-revisit-tangle/

# %%
    
    
    🍪 = λ['ipywidgets.IntSlider'](description=
Cookies!                          
                                   
                                   ,min=0, max=1000, value=3)
    return 🍪
# Out:
# IntSlider(value=3, description='Cookies!', max=1000)

# %%
    return 🍪

When you eat {{_cookie_.value}} cookies, you consume {{_cookie_.value*50}} calories.

{% if _cookie_.value > 10 %}# too many cookies (the band){% endif %}

{{_cookie_.value*"🍪"}}
# Out:
# IntSlider(value=3, description='Cookies!', max=1000)
#     return 🍪
#
# When you eat 3 cookies, you consume 150 calories.
#
#
#
# 🍪🍪🍪

# %%
## Projecting real data.

dataframes can be the subject of many works of literature.
the dataframe basis implicitly defines
multiple translations in formal representations
like charts, tables, and numbers

in `pidgy`, when your data changes, so do your displays.
# Out:
# ## Projecting real data.
#
# dataframes can be the subject of many works of literature.
# the dataframe basis implicitly defines
# multiple translations in formal representations
# like charts, tables, and numbers
#
# in `pidgy`, when your data changes, so do your displays.

# %%
    # NBVAL_IGNORE_OUTPUT
    df = __import__('pandas').util.testing.makeDataFrame()
    
re-running this cell with update the dataframe display.
# Out:
# /Users/tonyfast/anaconda3/lib/python3.7/site-packages/pandas/util/__init__.py:12: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#     # NBVAL_IGNORE_OUTPUT
#     df = __import__('pandas').util.testing.makeDataFrame()
#
# re-running this cell with update the dataframe display.

# %% [markdown]
# below is a graphical figure described in a caption using natural language, numbers, and programming languages.

# %%
    # NBVAL_IGNORE_OUTPUT
{{df.plot().figure}}

this is random data generated to prove a point
who knows what point?
but that i can do this!
and you can too!

below is a sample view of the data 

{{df.sample(2)}}

at an aggregate level data has the following measurements

{{df.describe().T}}

    df: "da f***?"
# Out:
#     # NBVAL_IGNORE_OUTPUT
# <img src="data:image/png;base64,..."/>
#
# this is random data generated to prove a point
# who knows what point?
# but that i can do this!
# and you can too!
#
# below is a sample view of the data
#
# <div><style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style><table border=1 class=dataframe><thead><tr style="text-align: right;"><th></th><th>A</th><th>B</th><th>C</th><th>D</th></tr></thead><tbody><tr><th>JmKR3Guizg</th><td>0.578496</td><td>-0.006285</td><td>-0.939661</td><td>-0.440261</td></tr><tr><th>KryqXAv6da</th><td>-1.475785</td><td>0.319211</td><td>0.124098</td><td>-1.516598</td></tr></tbody></table></div>
#
# at an aggregate level data has the following measurements
#
# <div><style scoped>
#     .dataframe tbody tr th:only-of-type {
# ...
